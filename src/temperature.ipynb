# %%
import pandas as pd

df_no_temp = pd.read_csv('../data/RFID_DATA_SET_NOTEMP_CLEANED.csv')
df_temp = pd.read_csv('../data/RFID_DATA_SET_TEMP_CLEANED.csv')

# %%
temp21 = []
temp25 = []
temp29 = []
temp33 = []
temp37 = []
r_temp21 = []
r_temp25 = []
r_temp29 = []
r_temp33 = []
r_temp37 = []

for t, r, i in zip(df_temp['Temperature'],df_temp['RSSI'],df_temp['Detect']):
    if t == 21:
        temp21.append(r)
        r_temp21.append(i)
    elif t == 25:
        temp25.append(r)
        r_temp25.append(i)
    elif t == 29:
        temp29.append(r)
        r_temp29.append(i)
    elif t == 33:
        temp33.append(r)
        r_temp33.append(i)
    elif t == 37:
        temp37.append(r)
        r_temp37.append(i)

# %%
# Relation RSSI with Temperature
from statistics import mean

all_temp = [mean(temp21), mean(temp25), mean(temp29), mean(temp33), mean(temp37)]
print(mean(temp21), mean(temp25), mean(temp29), mean(temp33), mean(temp37))
all_temp
# Out:
# 40.0575 75.5485 99.1255 82.735 93.589
# [40.0575, 75.5485, 99.1255, 82.735, 93.589]

# %%
# Relation Read Rate (%) with Temperature
allReadTemp = [mean(r_temp21)*100, mean(r_temp25)*100, mean(r_temp29)*100, mean(r_temp33)*100, mean(r_temp37)*100]
print(mean(r_temp21)*100, mean(r_temp25)*100, mean(r_temp29)*100, mean(r_temp33)*100, mean(r_temp37)*100)
allReadTemp
# Out:
# 30.55 54.15 73.45 65.55 66.60000000000001
# [30.55, 54.15, 73.45, 65.55, 66.60000000000001]

# %%
import matplotlib.pyplot as plt

x = sorted(df_temp['Temperature'].unique())
y = all_temp

plt.figure(figsize=(8,5))
plt.plot(x, y, color='green', linestyle='dashed', linewidth = 1, marker='o', markerfacecolor='blue', markersize=8.5)
plt.xlabel('Temperature')
plt.ylabel('RSSI')
plt.title('RSSI X Temperature')
plt.show()

# %%
x = sorted(df_temp['Temperature'].unique())
y = allReadTemp
plt.figure(figsize=(8,5))
plt.plot(x, y, color='pink', linestyle='dashed', linewidth = 1, marker='o', markerfacecolor='purple', markersize=8.5)

plt.xlabel('Temperature')
plt.ylabel('Read Rate (%)')
plt.title('Read Rate (%) X Temperature')
plt.show()

# %%
df_no_temp2 = df_no_temp[['Distance','RSSI','Detect']]
no_temp_dist_group = df_no_temp2.groupby('Distance')
no_temp_dist10 = no_temp_dist_group.get_group(10)
no_temp_dist20 = no_temp_dist_group.get_group(20)
no_temp_dist30 = no_temp_dist_group.get_group(30)
no_temp_dist40 = no_temp_dist_group.get_group(40)
no_temp_dist50 = no_temp_dist_group.get_group(50)
no_temp_dist60 = no_temp_dist_group.get_group(60)
no_temp_dist70 = no_temp_dist_group.get_group(70)
no_temp_dist80 = no_temp_dist_group.get_group(80)
no_temp_dist90 = no_temp_dist_group.get_group(90)
no_temp_dist100 = no_temp_dist_group.get_group(100)
no_temp_dist110 = no_temp_dist_group.get_group(110)
no_temp_dist120 = no_temp_dist_group.get_group(120)
no_temp_dist130 = no_temp_dist_group.get_group(130)
no_temp_dist140 = no_temp_dist_group.get_group(140)
no_temp_dist150 = no_temp_dist_group.get_group(150)
no_temp_dist160 = no_temp_dist_group.get_group(160)
no_temp_dist170 = no_temp_dist_group.get_group(170)
no_temp_dist180 = no_temp_dist_group.get_group(180)
no_temp_dist190 = no_temp_dist_group.get_group(190)
no_temp_dist200 = no_temp_dist_group.get_group(200)

all_rssi_no_temp = [mean(no_temp_dist10['RSSI']),mean(no_temp_dist20['RSSI']),mean(no_temp_dist30['RSSI']),mean(no_temp_dist40['RSSI']),mean(no_temp_dist50['RSSI'])
           ,mean(no_temp_dist60['RSSI']),mean(no_temp_dist70['RSSI']),mean(no_temp_dist80['RSSI']),mean(no_temp_dist90['RSSI']),mean(no_temp_dist100['RSSI'])
           ,mean(no_temp_dist110['RSSI']),mean(no_temp_dist120['RSSI']),mean(no_temp_dist130['RSSI']),mean(no_temp_dist140['RSSI']),mean(no_temp_dist150['RSSI']),
           mean(no_temp_dist160['RSSI']),mean(no_temp_dist170['RSSI']),mean(no_temp_dist180['RSSI']),mean(no_temp_dist190['RSSI']),mean(no_temp_dist200['RSSI'])]
# all_rssi_no_temp

# %%
temp_dist_group = df_temp.groupby('Distance')
temp_dist10 = temp_dist_group.get_group(10)
temp_dist20 = temp_dist_group.get_group(20)
temp_dist30 = temp_dist_group.get_group(30)
temp_dist40 = temp_dist_group.get_group(40)
temp_dist50 = temp_dist_group.get_group(50)
temp_dist60 = temp_dist_group.get_group(60)
temp_dist70 = temp_dist_group.get_group(70)
temp_dist80 = temp_dist_group.get_group(80)
temp_dist90 = temp_dist_group.get_group(90)
temp_dist100 = temp_dist_group.get_group(100)
temp_dist110 = temp_dist_group.get_group(110)
temp_dist120 = temp_dist_group.get_group(120)
temp_dist130 = temp_dist_group.get_group(130)
temp_dist140 = temp_dist_group.get_group(140)
temp_dist150 = temp_dist_group.get_group(150)
temp_dist160 = temp_dist_group.get_group(160)
temp_dist170 = temp_dist_group.get_group(170)
temp_dist180 = temp_dist_group.get_group(180)
temp_dist190 = temp_dist_group.get_group(190)
temp_dist200 = temp_dist_group.get_group(200)

# allRSSIDist = [mean(temp_dist10['RSSI']),mean(temp_dist20['RSSI']),mean(temp_dist30['RSSI']),mean(temp_dist40['RSSI']),mean(temp_dist50['RSSI'])
#            ,mean(temp_dist60['RSSI']),mean(temp_dist70['RSSI']),mean(temp_dist80['RSSI']),mean(temp_dist90['RSSI']),mean(temp_dist100['RSSI'])
#            ,mean(temp_dist110['RSSI']),mean(temp_dist120['RSSI']),mean(temp_dist130['RSSI']),mean(temp_dist140['RSSI']),mean(temp_dist150['RSSI']),
#            mean(temp_dist160['RSSI']),mean(temp_dist170['RSSI']),mean(temp_dist180['RSSI']),mean(temp_dist190['RSSI']),mean(temp_dist200['RSSI'])]
# allRSSIDist

# %%
all_rssi_rr_no_temp = [mean(no_temp_dist10['Detect']*100),mean(no_temp_dist20['Detect']*100),mean(no_temp_dist30['Detect']*100),mean(no_temp_dist40['Detect']*100),mean(no_temp_dist50['Detect']*100)
           ,mean(no_temp_dist60['Detect']*100),mean(no_temp_dist70['Detect']*100),mean(no_temp_dist80['Detect']*100),mean(no_temp_dist90['Detect']*100),mean(no_temp_dist100['Detect']*100)
           ,mean(no_temp_dist110['Detect']*100),mean(no_temp_dist120['Detect']*100),mean(no_temp_dist130['Detect']*100),mean(no_temp_dist140['Detect']*100),mean(no_temp_dist150['Detect']*100),
           mean(no_temp_dist160['Detect']*100),mean(no_temp_dist170['Detect']*100),mean(no_temp_dist180['Detect']*100),mean(no_temp_dist190['Detect']*100),mean(no_temp_dist200['Detect']*100)]
# all_rssi_rr_no_temp

# %%
# group by distance and temperature
sorted(df_temp['Temperature'].unique())
d10_t21 = temp_dist10.groupby('Temperature').get_group(21)['RSSI']
d10_t29 = temp_dist10.groupby('Temperature').get_group(29)['RSSI']
d20_t21 = temp_dist20.groupby('Temperature').get_group(21)['RSSI']
d20_t29 = temp_dist20.groupby('Temperature').get_group(29)['RSSI']
d30_t21 = temp_dist30.groupby('Temperature').get_group(21)['RSSI']
d30_t29 = temp_dist30.groupby('Temperature').get_group(29)['RSSI']
d40_t21 = temp_dist40.groupby('Temperature').get_group(21)['RSSI']
d40_t29 = temp_dist40.groupby('Temperature').get_group(29)['RSSI']
d50_t21 = temp_dist50.groupby('Temperature').get_group(21)['RSSI']
d50_t29 = temp_dist50.groupby('Temperature').get_group(29)['RSSI']
d60_t21 = temp_dist60.groupby('Temperature').get_group(21)['RSSI']
d60_t29 = temp_dist60.groupby('Temperature').get_group(29)['RSSI']
d70_t21 = temp_dist70.groupby('Temperature').get_group(21)['RSSI']
d70_t29 = temp_dist70.groupby('Temperature').get_group(29)['RSSI']
d80_t21 = temp_dist80.groupby('Temperature').get_group(21)['RSSI']
d80_t29 = temp_dist80.groupby('Temperature').get_group(29)['RSSI']
d90_t21 = temp_dist90.groupby('Temperature').get_group(21)['RSSI']
d90_t29 = temp_dist90.groupby('Temperature').get_group(29)['RSSI']
d100_t21 = temp_dist100.groupby('Temperature').get_group(21)['RSSI']
d100_t29 = temp_dist100.groupby('Temperature').get_group(29)['RSSI']
d110_t21 = temp_dist110.groupby('Temperature').get_group(21)['RSSI']
d110_t29 = temp_dist110.groupby('Temperature').get_group(29)['RSSI']
d120_t21 = temp_dist120.groupby('Temperature').get_group(21)['RSSI']
d120_t29 = temp_dist120.groupby('Temperature').get_group(29)['RSSI']
d130_t21 = temp_dist130.groupby('Temperature').get_group(21)['RSSI']
d130_t29 = temp_dist130.groupby('Temperature').get_group(29)['RSSI']
d140_t21 = temp_dist140.groupby('Temperature').get_group(21)['RSSI']
d140_t29 = temp_dist140.groupby('Temperature').get_group(29)['RSSI']
d150_t21 = temp_dist150.groupby('Temperature').get_group(21)['RSSI']
d150_t29 = temp_dist150.groupby('Temperature').get_group(29)['RSSI']
d160_t21 = temp_dist160.groupby('Temperature').get_group(21)['RSSI']
d160_t29 = temp_dist160.groupby('Temperature').get_group(29)['RSSI']
d170_t21 = temp_dist170.groupby('Temperature').get_group(21)['RSSI']
d170_t29 = temp_dist170.groupby('Temperature').get_group(29)['RSSI']
d180_t21 = temp_dist180.groupby('Temperature').get_group(21)['RSSI']
d180_t29 = temp_dist180.groupby('Temperature').get_group(29)['RSSI']
d190_t21 = temp_dist190.groupby('Temperature').get_group(21)['RSSI']
d190_t29 = temp_dist190.groupby('Temperature').get_group(29)['RSSI']
d200_t21 = temp_dist200.groupby('Temperature').get_group(21)['RSSI']
d200_t29 = temp_dist200.groupby('Temperature').get_group(29)['RSSI']

# %%
# read rate group by distance and temperature
sorted(df_temp['Temperature'].unique())
rr_d10_t21 = temp_dist10.groupby('Temperature').get_group(21)['Detect']
rr_d10_t29 = temp_dist10.groupby('Temperature').get_group(29)['Detect']
rr_d20_t21 = temp_dist20.groupby('Temperature').get_group(21)['Detect']
rr_d20_t29 = temp_dist20.groupby('Temperature').get_group(29)['Detect']
rr_d30_t21 = temp_dist30.groupby('Temperature').get_group(21)['Detect']
rr_d30_t29 = temp_dist30.groupby('Temperature').get_group(29)['Detect']
rr_d40_t21 = temp_dist40.groupby('Temperature').get_group(21)['Detect']
rr_d40_t29 = temp_dist40.groupby('Temperature').get_group(29)['Detect']
rr_d50_t21 = temp_dist50.groupby('Temperature').get_group(21)['Detect']
rr_d50_t29 = temp_dist50.groupby('Temperature').get_group(29)['Detect']
rr_d60_t21 = temp_dist60.groupby('Temperature').get_group(21)['Detect']
rr_d60_t29 = temp_dist60.groupby('Temperature').get_group(29)['Detect']
rr_d70_t21 = temp_dist70.groupby('Temperature').get_group(21)['Detect']
rr_d70_t29 = temp_dist70.groupby('Temperature').get_group(29)['Detect']
rr_d80_t21 = temp_dist80.groupby('Temperature').get_group(21)['Detect']
rr_d80_t29 = temp_dist80.groupby('Temperature').get_group(29)['Detect']
rr_d90_t21 = temp_dist90.groupby('Temperature').get_group(21)['Detect']
rr_d90_t29 = temp_dist90.groupby('Temperature').get_group(29)['Detect']
rr_d100_t21 = temp_dist100.groupby('Temperature').get_group(21)['Detect']
rr_d100_t29 = temp_dist100.groupby('Temperature').get_group(29)['Detect']
rr_d110_t21 = temp_dist110.groupby('Temperature').get_group(21)['Detect']
rr_d110_t29 = temp_dist110.groupby('Temperature').get_group(29)['Detect']
rr_d120_t21 = temp_dist120.groupby('Temperature').get_group(21)['Detect']
rr_d120_t29 = temp_dist120.groupby('Temperature').get_group(29)['Detect']
rr_d130_t21 = temp_dist130.groupby('Temperature').get_group(21)['Detect']
rr_d130_t29 = temp_dist130.groupby('Temperature').get_group(29)['Detect']
rr_d140_t21 = temp_dist140.groupby('Temperature').get_group(21)['Detect']
rr_d140_t29 = temp_dist140.groupby('Temperature').get_group(29)['Detect']
rr_d150_t21 = temp_dist150.groupby('Temperature').get_group(21)['Detect']
rr_d150_t29 = temp_dist150.groupby('Temperature').get_group(29)['Detect']
rr_d160_t21 = temp_dist160.groupby('Temperature').get_group(21)['Detect']
rr_d160_t29 = temp_dist160.groupby('Temperature').get_group(29)['Detect']
rr_d170_t21 = temp_dist170.groupby('Temperature').get_group(21)['Detect']
rr_d170_t29 = temp_dist170.groupby('Temperature').get_group(29)['Detect']
rr_d180_t21 = temp_dist180.groupby('Temperature').get_group(21)['Detect']
rr_d180_t29 = temp_dist180.groupby('Temperature').get_group(29)['Detect']
rr_d190_t21 = temp_dist190.groupby('Temperature').get_group(21)['Detect']
rr_d190_t29 = temp_dist190.groupby('Temperature').get_group(29)['Detect']
rr_d200_t21 = temp_dist200.groupby('Temperature').get_group(21)['Detect']
rr_d200_t29 = temp_dist200.groupby('Temperature').get_group(29)['Detect']

# %%
# Mean RSSI Temp21
all_rssi_dt21 = [mean(d10_t21),mean(d20_t21),mean(d30_t21),mean(d40_t21),mean(d50_t21)
           ,mean(d60_t21),mean(d70_t21),mean(d80_t21),mean(d90_t21),mean(d100_t21)
           ,mean(d110_t21),mean(d120_t21),mean(d130_t21),mean(d140_t21),mean(d150_t21),
           mean(d160_t21),mean(d170_t21),mean(d180_t21),mean(d190_t21),mean(d200_t21)]
# all_rssi_dt21

# Mean RSSI Temp29
all_rssi_dt29 = [mean(d10_t29),mean(d20_t29),mean(d30_t29),mean(d40_t29),mean(d50_t29)
           ,mean(d60_t29),mean(d70_t29),mean(d80_t29),mean(d90_t29),mean(d100_t29)
           ,mean(d110_t29),mean(d120_t29),mean(d130_t29),mean(d140_t29),mean(d150_t29),
           mean(d160_t29),mean(d170_t29),mean(d180_t29),mean(d190_t29),mean(d200_t29)]
# all_rssi_dt29

# %%
# Mean RSSI Temp21
all_rr_rssi_dt21 = [mean(rr_d10_t21)*100,mean(rr_d20_t21)*100,mean(rr_d30_t21)*100,mean(rr_d40_t21)*100,mean(rr_d50_t21)*100
           ,mean(rr_d60_t21)*100,mean(rr_d70_t21)*100,mean(rr_d80_t21)*100,mean(rr_d90_t21)*100,mean(rr_d100_t21)*100
           ,mean(rr_d110_t21)*100,mean(rr_d120_t21)*100,mean(rr_d130_t21)*100,mean(rr_d140_t21)*100,mean(rr_d150_t21)*100,
           mean(rr_d160_t21)*100,mean(rr_d170_t21)*100,mean(rr_d180_t21)*100,mean(rr_d190_t21)*100,mean(rr_d200_t21)]
# all_rr_rssi_dt21

# Mean RSSI Temp29
all_rr_rssi_dt29 = [mean(rr_d10_t29)*100,mean(rr_d20_t29)*100,mean(rr_d30_t29)*100,mean(rr_d40_t29)*100,mean(rr_d50_t29)*100
           ,mean(rr_d60_t29)*100,mean(rr_d70_t29)*100,mean(rr_d80_t29)*100,mean(rr_d90_t29)*100,mean(rr_d100_t29)*100
           ,mean(rr_d110_t29)*100,mean(rr_d120_t29)*100,mean(rr_d130_t29)*100,mean(rr_d140_t29)*100,mean(rr_d150_t29)*100,
           mean(rr_d160_t29)*100,mean(rr_d170_t29)*100,mean(rr_d180_t29)*100,mean(rr_d190_t29)*100,mean(rr_d200_t29)]
# all_rr_rssi_dt29

# %%
x = df_temp.Distance.unique()
plt.figure(figsize=(8,5))
plt.plot(x, all_rssi_no_temp, label='No Temperature', color='black', linestyle='dashed', linewidth = 1, marker='o', markerfacecolor='gray', markersize=6)
plt.plot(x, all_rssi_dt21, label='Temperature 21 ᵒC', color='crimson', linestyle='dashed', linewidth = 1, marker='^', markerfacecolor='pink', markersize=6)
plt.plot(x, all_rssi_dt29, label='Temperature 29 ᵒC', color='green', linestyle='dashed', linewidth = 1, marker='s', markerfacecolor='limegreen', markersize=6)

plt.legend()
plt.xlabel('Distance')
plt.ylabel('RSSI')
plt.title('RSSI X Distance')
plt.show()

# %%
x = df_temp.Distance.unique()
y = all_rssi_rr_no_temp
plt.figure(figsize=(8,5))
plt.plot(x, y, label='No Temperature', color='black', linestyle='dashed', linewidth = 1, marker='o', markerfacecolor='gray', markersize=6)
plt.plot(x, all_rr_rssi_dt21, label='Temperature 21 ᵒC', color='crimson', linestyle='dashed', linewidth = 1, marker='^', markerfacecolor='pink', markersize=6)
plt.plot(x, all_rr_rssi_dt29, label='Temperature 29 ᵒC', color='green', linestyle='dashed', linewidth = 1, marker='s', markerfacecolor='limegreen', markersize=6)

plt.legend()
plt.xlabel('Distance')
plt.ylabel('Read Rate (%)')
plt.title('Read Rate (%) X Distance')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np

dataset = df_temp.sort_values(by=['Temperature'])
X = dataset['Temperature'].to_frame()
y = dataset['RSSI'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

poly = PolynomialFeatures(degree=1)
x_poly = poly.fit_transform(X_train)
poly.fit(X_train, y_train)
model = LinearRegression()
model.fit(x_poly, y_train)

# plt.scatter(X_test, y_test, color='red')
y_pred = model.predict(poly.fit_transform(X_test))
r2 = r2_score(y_test, y_pred)

#predict the future
y_pred1 = model.predict(poly.fit_transform([[17]]))
y_pred2 = model.predict(poly.fit_transform([[19]]))
y_pred3 = model.predict(poly.fit_transform([[39]]))
y_pred4 = model.predict(poly.fit_transform([[41]]))
# add future value to set of np predicted value
y_pred = np.append(y_pred, [y_pred1])
y_pred = np.append(y_pred, [y_pred2])
y_pred = np.append(y_pred, [y_pred3])
y_pred = np.append(y_pred, [y_pred4])
# add future value to set of np year value
a = X_test.values
a = np.append(a, [17])
a = np.append(a, [19])
a = np.append(a, [39])
a = np.append(a, [41])
dfa = pd.DataFrame(a, columns=['Temperature'])
a1 = dfa['Temperature'].to_frame()

# plt.scatter(X_test, y_test, color='red')]
plt.figure(figsize=(8,5))
plt.plot(a1, y_pred, color='blue',marker='o',linestyle='dashed', markerfacecolor='blue', markersize=8)
plt.plot(sorted(df_temp['Temperature'].unique()), all_temp, linestyle='dashed', color='Green',marker='o', markerfacecolor='Green', markersize=8)
plt.title('RSSI x Temperature')
plt.xlabel('Temperature')
plt.ylabel('RSSI')
plt.legend(['Predicted Line', 'Actual data','Observation data'])
plt.figtext(.01, .04, "r2 = "+str(r2))
plt.figtext(.01, 1, " 17C " + str(y_pred1)+" 19C " + str(y_pred2)+" 39C " + str(y_pred3)
           +" 41C "+str(y_pred4))
plt.show()
